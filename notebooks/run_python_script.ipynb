# %%
# Core libraries
from google.colab import drive
# Mount my drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Install Darts library
# !pip install darts "darts[torch]" --quiet
# Out:
# WARNING: darts 0.38.0 does not provide the extra 'torch'

# %%
# Copy the script from my drive (change the path as needed)
# !cp /content/drive/MyDrive/Appled-Data-Science/Code/tft_prediction.py .

# %%
# Run the script
# !python tft_prediction.py
# Out:
# The StatsForecast module could not be imported. To enable support for the AutoARIMA, AutoETS and Croston models, please consider installing it.
#
# ...
# Seoul Bike Rental - TFT Prediction Pipeline
# Multiple Prediction Horizons: 1h, 24h, 3d
# ...
#
# [Step 1] Loading raw data...
# ✓ Data loaded. Shape: (8760, 14)
#
# [Step 2] Preprocessing data and engineering features...
# ✓ Basic data preprocessing completed
# ✓ Feature engineering completed
#   Total features: 18
# ✓ Converted to TimeSeries format
#   Target shape: (8760, 1, 1)
#   Features shape: (8760, 16, 1)
#
# [Step 3] Initializing predictor with multiple horizon models...
# ✓ 1-hour ahead model loaded from: /content/drive/My Drive/Appled-Data-Science/Data/tft_1h.pt
# ✓ 24-hour ahead model loaded from: /content/drive/My Drive/Appled-Data-Science/Data/tft_24h.pt
# ✓ 3-day ahead model loaded from: /content/drive/My Drive/Appled-Data-Science/Data/tft_3d.pt
#
# ✓ 3/3 models loaded successfully
#
# [Step 3.5] Scaling data for predictions...
# ...
